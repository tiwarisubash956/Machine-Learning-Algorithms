# %% [markdown]
# <a href="https://colab.research.google.com/github/tiwarisubash956/Machine-Learning-Algorithms/blob/main/PyTorch_Training_Pipeline_manually.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.drop(columns=['Unnamed: 32','id'],inplace=True)

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# **Train_test_split**

# %%
X=df.iloc[:, 1:]
y=df.iloc[:,0]

# %%
X_train,X_test,y_train_,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# **Scaling**

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# **Label Encoding**

# %%
encoder=LabelEncoder()
y_train=encoder.fit_transform(y_train_)
y_test=encoder.transform(y_test)

# %% [markdown]
# Numpy array to tensor

# %%
X_train_tensor=torch.from_numpy(X_train)
X_test_tensor=torch.from_numpy(X_test)
y_train_tensor=torch.from_numpy(y_train)
y_test_tensor=torch.from_numpy(y_test)

# %%
X_train
# Out:
# array([[-0.01330339,  1.7757658 , -0.01491962, ..., -0.13236958,
#         -1.08014517, -0.03527943],
#        [-0.8448276 , -0.6284278 , -0.87702746, ..., -1.11552632,
#         -0.85773964, -0.72098905],
#        [ 1.44755936,  0.71180168,  1.47428816, ...,  0.87583964,
#          0.4967602 ,  0.46321706],
#        ...,
#        [-0.46608541, -1.49375484, -0.53234924, ..., -1.32388956,
#         -1.02997851, -0.75145272],
#        [-0.50025764, -1.62161319, -0.527814  , ..., -0.0987626 ,
#          0.35796577, -0.43906159],
#        [ 0.96060511,  1.21181916,  1.00427242, ...,  0.8956983 ,
#         -1.23064515,  0.50697397]])

# %%
loss_function=nn.BCELoss()

# %% [markdown]
# **Defining the model**

# %%
class MysimpleNeuralNetwork(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.network=nn.Sequential(
      nn.Linear(num_features,1),
      # nn.ReLU(),
      # nn.Linear(3,1),
      nn.Sigmoid()
    )

  def forward(self,X):
    y_pred=self.network(X)
    return y_pred

  def backward(self,X,y_pred,y):
    pass

# %% [markdown]
# **Important Paramters**

# %%
learning_rate=0.1
epoches=25

# %% [markdown]
# **Training Pipeline**

# %%
# create model
model=MysimpleNeuralNetwork(X_test_tensor.shape[1])
# define loop

for epoch in range(epoches):
  # forward pass
  y_pred=model(X_train_tensor.view(-1,1))
  # loss calculate
  loss=loss_function(y_pred,y_train)
  print(f'epoch: {epoch+1}, loss = {loss.item():.4f}')

  # backward pass
  loss.backward()

  # parameter update
  with torch.no_grad():
    model.weights -= learning_rate * model.weights.grad
    model.bias -= learning_rate * model.bias.grad
  # zero grad
  model.weights.grad.zero_()
  model.bias.grad.zero_()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_1717/2133041912.py in <cell line: 0>()
#       5 for epoch in range(epoches):
#       6   # forward pass
# ----> 7   y_pred=model(X_train_tensor.view(-1,1))
#       8   # loss calculate
#       9   loss=loss_function(y_pred,y_train)
#
# RuntimeError: view size is not compatible with input tensor's size and stride (at least one dimension spans across two contiguous subspaces). Use .reshape(...) instead.

# %%
model.weights

# %%
model.bias

# %% [markdown]
# **Evaluation**

# %%
# model evaluation
with torch.no_grad():
  y_pred=model.forward(X_test_tensor)
  y_pred_class=y_pred.round()
  acc=accuracy_score(y_test,y_pred_class)
  print(acc)

# %% [markdown]
# # **Using nn Module building the Neural Network**

# %%
# create model class
import torch

class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.linear=nn.Linear(num_features,1)
    self.sigmoid=nn.Sigmoid()
  def forward(self,features):
    out=self.linear(features)
    out=self.sigmoid(out)
    return out

# %%
# create dataset
feature=torch.rand(10,5)
# create model
model=Model(feature.shape[1])
# forward pass
output=model(feature)
print(output)

# %%
# show model weights
model.linear.bias

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

# %%
summary(model,input_size=(10,5))

# %% [markdown]
# **building the neural network with hidden layer**
# # I:n input layer there are  5 input  ,hidden layer consists of 3 layer and one output

# %%
# create model class
import torch
import torch.nn as nn

class Model2(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.network=nn.Sequential(
        nn.Linear(num_features,3),
        nn.ReLU(),
        nn.Linear(3,1),
        nn.Sigmoid()
    )

  def forward(self,features):
    out=self.network(features)
    return out

# %%
# create dataset
feature=torch.rand(10,5)
# create model
model=Model2(feature.shape[1])
# forward pass
output=model(feature)
print(output)

# %%
summary(model,input_size=(10,5))
