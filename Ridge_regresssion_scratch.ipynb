# %% [markdown]
# <a href="https://colab.research.google.com/github/tiwarisubash956/Machine-Learning-Algorithms/blob/main/Ridge_regresssion_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import  make_regression
from sklearn.model_selection import train_test_split
import numpy as np

# %%
X,y=make_regression(n_samples=500,n_features=1,noise=2)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
class MeroLr:
  def __init__(self,alpha=0.1):
    self.alpha=alpha
    self.m=None
    self.b=None

  def fit(self,X_train,y_train):
    num=0
    den=0
    for i in range(X_train.shape[0]):
      num+=(X_train[i]-X_train.mean())*(y_train[i]-y_train.mean())
      den+=(X_train[i]-X_train.mean())

    self.m=num/(den+self.alpha)
    self.b=y_train.mean()-(self.m*X_train.mean())
    print(self.m)
    print(self.b)



  def predict(X_test):
    pass

# %%
reg=MeroLr(alpha=10)

# %%
reg.fit(X_train,y_train)
# Out:
# [3224.55027046]
# [100.0027724]

# %% [markdown]
# **For N dimeansion**

# %% [markdown]
# **Sklearn**

# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import  r2_score
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split

# %%
X,y=load_diabetes(return_X_y=True)

# %%
X_train1,X_test1,y_train1,y_test1=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg=Ridge(alpha=0.1,solver='cholesky')

# %%
reg.fit(X_train1,y_train1)
# Out:
# Ridge(alpha=0.1, solver='cholesky')

# %%
y_pred=reg.predict(X_test1)
r2_score(y_test1,y_pred)
# Out:
# 0.45199494197195456

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [   6.64373321 -172.23747375  485.52958514  314.67584612  -72.94020918
#   -80.58868817 -174.46352722   83.61470987  484.36531622   73.58509056]
# 151.92546856900984

# %% [markdown]
# **Manually**

# %%
class MeroLr2:
  def __init__(self,alpha=0.1):
    self.alpha=alpha
    self.m1=None
    self.b1=None

  def fit(self,X_train1,y_train1):
    X_train1=np.insert(X_train1,0,1,axis=1)
    num1=0
    den1=0
    I=np.identity(X_train1.shape[1])
    result=np.linalg.inv(np.dot(X_train1.T,X_train1)+self.alpha*I).dot(X_train1.T).dot(y_train1)
    self.b1=result[0]
    self.m1=result[1:]
    print(self.m1)
    print(self.b1)



  def predict(self,X_test):
    return np.dot(X_test,self.m1)+self.b1

# %%
l2=MeroLr2()
l2.fit(X_train1,y_train1)
# Out:
# [   6.64970105 -172.2493574   485.49941498  314.68335483  -72.93919534
#   -80.6014393  -174.45279965   83.5733994   484.39865564   73.58483208]
# 151.88221592211522

# %%
y_pred=l2.predict(X_test1)
r2_score(y_test1,y_pred)
# Out:
# 0.4519719082031616
