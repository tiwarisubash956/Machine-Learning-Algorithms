# %% [markdown]
# <a href="https://colab.research.google.com/github/tiwarisubash956/Machine-Learning-Algorithms/blob/main/snake_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
! kaggle datasets download -d goelyash/165-different-snakes-species
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/goelyash/165-different-snakes-species
# License(s): Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)
# ...
# 100% 3.20G/3.20G [00:36<00:00, 94.4MB/s]

# %%
# unzip the file
import zipfile
zip_ref = zipfile.ZipFile('/content/165-different-snakes-species.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from keras import Sequential
from keras.preprocessing  import image
from PIL import Image
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout

# %%
df=pd.read_csv('/content/Csv/test.csv')
df.head()
# df.shape
df.tail()
# Out:
#       Unnamed: 0               binomial    country continent         genus  \
# 3133        3133  Xenochrophis piscator  Indonesia      Asia  Xenochrophis
# 3134        3134  Xenochrophis piscator   Cambodia      Asia  Xenochrophis
# 3135        3135  Xenochrophis piscator    unknown   unknown  Xenochrophis
# 3136        3136  Xenochrophis piscator      India      Asia  Xenochrophis
# 3137        3137  Xenochrophis piscator    unknown   unknown  Xenochrophis
#
#           family                              UUID  class_id  \
# 3133  Colubridae  0ea9d660f6a847c38c7463e3cb3ab1d0       758
# 3134  Colubridae  e2bf9314f68a4ba0b1c8e0ef962a1f83       758
# 3135  Colubridae  a488a9ec11254db19a776c861d01149f       758
# 3136  Colubridae  7d9a929f11824f74ba56dd475eac86ca       758
# 3137  Colubridae  c37c4c7f7a0746e2816c356c40627f8c       758
#
#            snake_sub_family  poisonous
# 3133  Xenochrophis piscator          0
# 3134  Xenochrophis piscator          0
# ...
